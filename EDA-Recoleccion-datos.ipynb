# %%
import pandas as pd

# %%
pd.read_excel("./Data/Pen Sales Data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\PycharmProjects\PythonProjectCostoDeEnvio\.venv\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
pd.read_excel("./Data/Pen Sales Data.xlsx")
# Out:
#     Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0       5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1       5202               Sharpies     12.99           0.00    2023-05-01
# 2       5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3       5204               Gel Pens      5.99           2.99    2023-05-01
# 4       5205        Rollerball Pens     12.99           1.99    2023-05-01
# 5       5206      Gel Pens (Pastel)     14.99           1.99    2023-05-01
# 6       5207        Rollerball Pens     12.99           1.99    2023-05-01
# 7       5208        Rollerball Pens     12.99           1.99    2023-05-01
# 8       5209               Gel Pens      5.99           2.99    2023-05-01
# 9       5210      Gel Pens (Pastel)     14.99           4.99    2023-05-01
# 10      5211  Ballpoint Pens (Bold)      6.95           0.00    2023-05-01
# ...
